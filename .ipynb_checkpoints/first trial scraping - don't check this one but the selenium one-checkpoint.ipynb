# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urlparse
import json
import pandas as pd
from datetime import date

#use datetime to create the url

# %%
date.today()
# Out:
# datetime.date(2021, 7, 20)

# %%
today = date.today() 
year = today.year
day = today.day
month = today.month

# %%
tomorrow = datetime.date.today() + datetime.timedelta(days=1)
yeartm = tomorrow.year
daytm = tomorrow.day
monthtm = tomorrow.month

# %%
year = str(year)
day = str(day)
month = str(month)
yeartm = str(yeartm)
daytm = str(daytm)
monthtm = str(monthtm)

# %%
urltime = "https://www.booking.com/searchresults.nl.html?aid=376373&label=Boekings-nl-Nmlwg4ZjCgLYTSLOHsJrjgS267724993818%3Apl%3Ata%3Ap1%3Ap22.563.000%3Aac%3Aap%3Aneg%3Afi%3Atikwd-65526620%3Alp9043480%3Ali%3Adec%3Adm%3Appccp%3DUmFuZG9tSVYkc2RlIyh9YfpWGnRw6lOGtdKYocc2a8Y&sid=552e2254bbf42007c1fa7f86a7c26c19&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.nl.html%3Faid%3D376373%3Blabel%3DBoekings-nl-Nmlwg4ZjCgLYTSLOHsJrjgS267724993818%253Apl%253Ata%253Ap1%253Ap22.563.000%253Aac%253Aap%253Aneg%253Afi%253Atikwd-65526620%253Alp9043480%253Ali%253Adec%253Adm%253Appccp%253DUmFuZG9tSVYkc2RlIyh9YfpWGnRw6lOGtdKYocc2a8Y%3Bsid%3D552e2254bbf42007c1fa7f86a7c26c19%3Bsb_price_type%3Dtotal%26%3B&ss=Hamburg&is_ski_area=0&ssne=Hamburg&ssne_untouched=Hamburg&dest_id=-1785434&dest_type=city&checkin_year=" + year + "&checkin_month=" + month + "&checkin_monthday=" + day + "&checkout_year=" + yeartm + "&checkout_month=" + monthtm + "&checkout_monthday=" + daytm + "&group_adults=1&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1"

# %%
urltime
# Out:
# 'https://www.booking.com/searchresults.nl.html?aid=376373&label=Boekings-nl-Nmlwg4ZjCgLYTSLOHsJrjgS267724993818%3Apl%3Ata%3Ap1%3Ap22.563.000%3Aac%3Aap%3Aneg%3Afi%3Atikwd-65526620%3Alp9043480%3Ali%3Adec%3Adm%3Appccp%3DUmFuZG9tSVYkc2RlIyh9YfpWGnRw6lOGtdKYocc2a8Y&sid=552e2254bbf42007c1fa7f86a7c26c19&sb=1&sb_lp=1&src=index&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.nl.html%3Faid%3D376373%3Blabel%3DBoekings-nl-Nmlwg4ZjCgLYTSLOHsJrjgS267724993818%253Apl%253Ata%253Ap1%253Ap22.563.000%253Aac%253Aap%253Aneg%253Afi%253Atikwd-65526620%253Alp9043480%253Ali%253Adec%253Adm%253Appccp%253DUmFuZG9tSVYkc2RlIyh9YfpWGnRw6lOGtdKYocc2a8Y%3Bsid%3D552e2254bbf42007c1fa7f86a7c26c19%3Bsb_price_type%3Dtotal%26%3B&ss=Hamburg&is_ski_area=0&ssne=Hamburg&ssne_untouched=Hamburg&dest_id=-1785434&dest_type=city&checkin_year=2021&checkin_month=7&checkin_monthday=20&checkout_year=2021&checkout_month=7&checkout_monthday=21&group_adults=1&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1'

# %% [markdown]
# # Parsing it (Soma's way)

# %%
response = requests.get(urltime)
doc = BeautifulSoup(response.text, 'html.parser')

# %%
#let's look at the doc
#it should give 25 hotels, including 'GINN hotel'
#however, it's not showing up. What's wrong?

# %%
doc
# Out:
# <!DOCTYPE html>
#
# <!--
# You know you could be getting paid to poke around in our code?
# We're hiring designers and developers to work in Amsterdam:
# https://careers.booking.com/
# -->
# <!-- wdot-802 -->
# <script nonce="K1kLW5Ph1ocREa4" src="https://cdn.cookielaw.org/consent/3ea94870-d4b1-483a-b1d2-faf1d982bb31/OtAutoBlock.js" type="text/javascript"></script>
# <script data-domain-script="3ea94870-d4b1-483a-b1d2-faf1d982bb31" nonce="K1kLW5Ph1ocREa4" src="https://cf.bstatic.com/libs/privacy-consent/1.0.1/customer/cookie-banner.min.js" type="text/javascript"></script>
# <script nonce="K1kLW5Ph1ocREa4" type="text/javascript">
# (function () {
# document.addEventListener('cookie_banner_closed', function(e) {
# if (window.PCM && window.B && window.B.et) {
# window.B.et.goal((window.PCM.Marketing || window.PCM.Analytical) ? 'cookie_consent_accepted_policy_banner' : 'cookie_consent_declined_policy_banner');
# }
# });
# document.addEventListener('click', function(e) {
# if (e.target && e.target.classList.contains('ot-preference-center-footer')) {
# e.preventDefault();
# Optanon && Optanon.ToggleInfoDisplay();
# }
# });
# })();
# </script>
# <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://cf.bstatic.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://shelves.booking.com/" rel="preconnect"/>
# <html class="noJS b_bot b_bot supports_fontface supports_hyphens" lang="nl" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# booking_com: http://ogp.me/ns/fb/booking_com#">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta content="origin" name="referrer"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type">
# <script nonce="K1kLW5Ph1ocREa4"> function b_cors_check(supported) { var value = supported ? 1 : 0; if (!/(^|;)\s*cors_js=/.test(document.cookie)) { var d = new Date(); d.setTime(d.getTime() + 60 * 60 * 24 * 365 * 1000); var cookieDomain = '.booking.com' || '.booking.com'; document.cookie = 'cors_js=' + value +'; domain=' + cookieDomain + '; path=/; expires=' + d.toGMTString(); } if (!value) { location.reload(); } } </script>
# <script nonce="K1kLW5Ph1ocREa4">(function(d) { d.addEventListener('error', function(e) { if (e.target && e.target.classList.contains('crossorigin-check-js')) { b_cors_check(false); } }, true); })(document); </script>
# <script async="" class="crossorigin-check-js" crossorigin="" nonce="K1kLW5Ph1ocREa4" src="https://cf.bstatic.com/static/js/crossorigin_check_cloudfront_sd/2454015045ef79168d452ff4e7f30bdadff0aa81.js"></script>
# <script nonce="K1kLW5Ph1ocREa4">
# ;(function() {
# window.b_early_errors = window.b_early_errors || [];
# window.onerror = function() {
# window.b_early_errors.push(arguments);
# };
# }());
#  </script>
# <link data-main-css="1" href="https://cf.bstatic.com/static/css/main_cloudfront_sd.iq_ltr/87ad15f1a24e1b1c35926a8fc20d70cca0649cb3.css" id="main-css-preload" rel="stylesheet">
# <script nonce="K1kLW5Ph1ocREa4">
# document.querySelector('#main-css-preload').addEventListener('load', function() {
# window.mainCssWasLoaded = 1;
# })
# </script>
# <link href="https://cf.bstatic.com/static/css/main_exps_cloudfront_sd.iq_ltr/1113dfedf11ff5384a3a774386fe790d54f9bc81.css" rel="stylesheet">
# <link href="https://cf.bstatic.com/static/css/gprof_icons_cloudfront_sd.iq_ltr/e6dd1c17b472583773a90eeabdd4e4b7c5e8170c.css" rel="stylesheet">
# <link data-defer-prefetch="" href="https://cf.bstatic.com/static/css/searchresults_cloudfront_sd.iq_ltr/9dd837920987b5cfa928a864f74604fe7b2e5716.css" rel="_prefetch"/>
# <link href="https://cf.bstatic.com/static/css/xp-index-sb_cloudfront_sd.iq_ltr/e35888f929bb16deaddc837ff43afce20a15a437.css" media="screen, print" rel="stylesheet" type="text/css">
# <link href="https://cf.bstatic.com/static/css/incentives_cloudfront_sd.iq_ltr/3233930c9c7955e590dad6914391e87fa532725a.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://cf.bstatic.com/static/css/city_cloudfront_sd.iq_ltr/de68be0e753c6e65031d00ab3140520a1e8efdf0.css" rel="stylesheet"/>
# <style> #basiclayout, .basiclayout { margin: 0; } #special_actions { margin: 3px 15px 3px 0; } .ticker_space { margin-top: 3px !important; } #logo_no_globe_new_logo { top: 14px; } .b_msie_6 #top, .b_msie_6 body.header_reshuffle #top {height:61px !important;} .b_msie_6 #special_actions { margin: 3px 15px 3px 0; overflow:visible; } body.header_reshuffle #top { min-height: 50px !important; height: auto !important; } .nobg { background: #fff url("https://cf.bstatic.com/static/img/nobg_all_blue_iq/b700d9e3067c1186a3364012df4fe1c48ae6da44.png") repeat-x; background-position: 0 -50px; } </style>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/core-deps-inlinedet_cloudfront_sd/4e2203ea8e576ee9aaab4ddd52b59054ec915695.js" nonce="K1kLW5Ph1ocREa4" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/jquery_cloudfront_sd/b7d9d30c56875df3553b561b0a06e5edf66aa9fe.js" nonce="K1kLW5Ph1ocREa4" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/main_cloudfront_sd/cc38340ded3a56e008259f0b185c77669f14d677.js" nonce="K1kLW5Ph1ocREa4" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/city_cloudfront_sd/76852a1cdc20bd6109c6a068e408ee32da780bd0.js" nonce="K1kLW5Ph1ocREa4" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/searchbox_cloudfront_sd/c07252028cfe39a8998d5d7f9157f03086358102.js" nonce="K1kLW5Ph1ocREa4" rel="preload"/>
# <link as="script" crossorigin="" href="https://cf.bstatic.com/static/js/error_catcher_bec_cloudfront_sd/f56f7a2e7854715ad5ecc2f07a1a4c7b4a49970d.js" nonce="K1kLW5Ph1ocREa4" rel="preload"/>
# <script nonce="K1kLW5Ph1ocREa4"> if( window.performance && performance.measure && 'b-stylesheets') { performance.measure('b-stylesheets'); } </script>
# <script nonce="K1kLW5Ph1ocREa4"> var lzimg = function(state){lzimg.state = state}; </script> <script async="" crossorigin="" nonce="K1kLW5Ph1ocREa4" src="https://cf.bstatic.com/static/js/lazy_load_images_cloudfront_sd/77204d4da4aa41b08b1a4062c8e66e4629550994.js"></script>
# <title>De 10 beste hotels in Hamburg, Duitsland (Prijzen vanaf € 35)</title>
# <meta content="Bespaar aanzienlijk op online hotels in Hamburg, Duitsland. Goede beschikbaarheid en geweldige prijzen. Lees hotelbeoordelingen en kies voor uw verblijf het hotel met de beste aanbieding." name="description"/>
# <meta content="hotel, Hotels, Hamburg, kamers, huisjes, accommodatie, speciale aanbiedingen, arrangementen, weekendjes weg, stedentrips Hamburg Duitsland, budget, goedkoop, korting, besparing" name="keywords"/>
# <meta content="index,follow" name="robots"/>
# <link href="https://www.booking.com/city/de/hamburg.nl.html" rel="canonical">
# <meta content="UmFuZG9tSVY07Cvt9NkbV1RmvVAIOn-I3HgJjKK-q287M8LGkcU9E51bqOaLa-EKn421F4S5Y-J8PBZELWvSpxuI_aRgNJByYvqOso9Cx0WvuW6hOf1c38K1CB2pVOcO3fAuhjIAGNceTHNu90WwYPzwg41kcepd8jCFDnvb8VRNZrsyK5DMGzgMrCZp8I8N3wrOTRo22TZi5yS56sTIZJYyyZc_wQhJit3fbX5HSmdgAxlKliQXxHjkwjiYDpSZcoTBr06zMKvJ6r_eEUyHZ13PH8w4-D1FOKl7D6EuZVQ94USOnfe5c98qcLniSx27HmM3VRwEOqU" name="booking-verification"/>
# <meta content="367003839" name="twitter:app:id:iphone"/>
# <meta content="Booking.com Hotel Reservations Worldwide &amp; Hotel Deals" name="twitter:app:name:ipad"/>
# <meta content="367003839" name="twitter:app:id:ipad"/>
# <meta content="Booking.com Hotel Reservations" name="twitter:app:name:googleplay"/>
# <meta content="com.booking" name="twitter:app:id:googleplay"/>
# <meta content="367003839" property="al:ios:app_store_id"/>
# <meta content="Booking.com Hotel Reservations" property="al:ios:app_name"/>
# <meta content="Booking.com Hotel Reservation" property="al:android:app_name"/>
# <meta content="com.booking" property="al:android:package"/>
# <meta content="723 hotels in Hamburg, Duitsland." name="twitter:title">
# <meta content="Bespaar aanzienlijk op online hotels in Hamburg, Duitsland. Goede beschikbaarheid en geweldige prijzen. Lees hotelbeoordelingen en kies voor uw verblijf het hotel met de beste aanbieding." name="twitter:description">
# <meta content="https://cf.bstatic.com/xdata/images/explorer_city/1680x560/10666.jpg?k=55fd284e486a292304484a814ff2cd9eed9f731ffe4177dd18f17692d83192d1&amp;o=" name="twitter:image">
# <meta content="booking://searchresults?dest_id=-1785434&amp;dest_type=city&amp;affiliate_id=375119" property="al:ios:url">
# <meta content="booking://searchresults?dest_id=-1785434&amp;dest_type=city&amp;affiliate_id=375119" property="al:android:url"/>
# <meta content="ff7f0b90ebb93e5bf7c7cafe77640ec1" name="p:domain_verify"/>
# <meta content="nl" http-equiv="content-language"/>
# <meta content="text/javascript" http-equiv="content-script-type"/>
# <meta content="text/css" http-equiv="content-style-type"/>
# <meta content="_top" http-equiv="window-target"/>
# <meta content="131840030178250, 1425349334428496, 117615518393985, 1565844503706287, 517612321758712, 1668799180037291, 265097377176252, 1643712662515912, 303492549842824, 1638321783047271, 809709019119342, 959185470826086, 217466488652137, 641365839348517, 203741606405114" property="fb:pages"/>
# <meta content="48970bbca45d28c2" property="wb:webmaster">
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@bookingcom" name="twitter:site"/>
# <meta content="@bookingcom" name="twitter:creator"/>
# <meta content="website" property="og:type">
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@bookingcom" name="twitter:site"/>
# <meta content="@bookingcom" name="twitter:creator"/>
# <meta content="723 hotels in Hamburg, Duitsland." property="og:title">
# <meta content="https://cf.bstatic.com/xdata/images/explorer_city/1680x560/10666.jpg?k=55fd284e486a292304484a814ff2cd9eed9f731ffe4177dd18f17692d83192d1&amp;o=" property="og:image">
# <meta content="Bespaar aanzienlijk op online hotels in Hamburg, Duitsland. Goede beschikbaarheid en geweldige prijzen. Lees hotelbeoordelingen en kies voor uw verblijf het hotel met de beste aanbieding." property="og:description">
# <meta content="nl_NL" property="og:locale">
# <meta content="https://www.booking.com/city/de/hamburg.nl.html" property="og:url">
# <meta content="Booking.com" property="og:site_name"/>
# <meta content="145362478954725" property="fb:app_id"/>
# <link href="https://www.booking.com/city/de/hamburg.en-gb.html" hreflang="en-gb" rel="alternate" title="English (UK)" type="text/html">
# <link href="https://www.booking.com/city/de/hamburg.html" hreflang="en-us" rel="alternate" title="English (US)" type="text/html">
# <link href="https://www.booking.com/city/de/hamburg.de.html" hreflang="de" rel="alternate" title="Deutsch" type="text/html">
# <link href="https://www.booking.com/city/de/hamburg.nl.html" hreflang="nl" rel="alternate" title="Nederlands" type="text/html">
# <link href="https://www.booking.com/city/de/hamburg.fr.html" hreflang="fr" rel="alternate" title="Français" type="text/html">
# <link href="https://www.booking.com/city/de/hamburg.es.html" hreflang="es" rel="alternate" title="Español" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.es-ar.html" hreflang="es-ar" rel="alternate" title="Español (AR)" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.es-mx.html" hreflang="es-mx" rel="alternate" title="Español (MX)" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.ca.html" hreflang="ca" rel="alternate" title="Català" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.it.html" hreflang="it" rel="alternate" title="Italiano" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.pt-pt.html" hreflang="pt-pt" rel="alternate" title="Português (PT)" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.pt-br.html" hreflang="pt-br" rel="alternate" title="Português (BR)" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.no.html" hreflang="no" rel="alternate" title="Norsk" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.fi.html" hreflang="fi" rel="alternate" title="Suomi" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.sv.html" hreflang="sv" rel="alternate" title="Svenska" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.da.html" hreflang="da" rel="alternate" title="Dansk" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.cs.html" hreflang="cs" rel="alternate" title="Čeština" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.hu.html" hreflang="hu" rel="alternate" title="Magyar" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.ro.html" hreflang="ro" rel="alternate" title="Română" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.ja.html" hreflang="ja" rel="alternate" title="日本語" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.zh-cn.html" hreflang="zh-cn" rel="alternate" title="简体中文" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.zh-tw.html" hreflang="zh-tw" rel="alternate" title="繁體中文" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.pl.html" hreflang="pl" rel="alternate" title="Polski" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.el.html" hreflang="el" rel="alternate" title="Ελληνικά" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.ru.html" hreflang="ru" rel="alternate" title="Русский" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.tr.html" hreflang="tr" rel="alternate" title="Türkçe" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.bg.html" hreflang="bg" rel="alternate" title="Български" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.ar.html" hreflang="ar" rel="alternate" title="العربية" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.ko.html" hreflang="ko" rel="alternate" title="한국어" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.he.html" hreflang="he" rel="alternate" title="עברית" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.lv.html" hreflang="lv" rel="alternate" title="Latviski" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.uk.html" hreflang="uk" rel="alternate" title="Українська" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.id.html" hreflang="id" rel="alternate" title="Bahasa Indonesia" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.ms.html" hreflang="ms" rel="alternate" title="Bahasa Malaysia" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.th.html" hreflang="th" rel="alternate" title="ภาษาไทย" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.et.html" hreflang="et" rel="alternate" title="Eesti" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.hr.html" hreflang="hr" rel="alternate" title="Hrvatski" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.lt.html" hreflang="lt" rel="alternate" title="Lietuvių" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.sk.html" hreflang="sk" rel="alternate" title="Slovenčina" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.sr.html" hreflang="sr" rel="alternate" title="Srpski" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.sl.html" hreflang="sl" rel="alternate" title="Slovenščina" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.vi.html" hreflang="vi" rel="alternate" title="Tiếng Việt" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.tl.html" hreflang="tl" rel="alternate" title="Filipino" type="text/html"/>
# <link href="https://www.booking.com/city/de/hamburg.is.html" hreflang="is" rel="alternate" title="Íslenska" type="text/html"/>
# <link href="https://cf.bstatic.com/static/img/b25logo/favicon/ebc77706da3aae4aee7b05dadf182390f0d26d11.ico" rel="shortcut icon"/>
# <link href="https://cf.bstatic.com/static/img/apple-touch-icon/c9b35bf29a75cac2f430f80a5d4bc7fd961d21a7.png" rel="apple-touch-icon"/>
# <link href="/faq.nl.html;" rel="help"/>
# <link href="https://cf.bstatic.com/static/opensearch/nl/575c46d4f22218790bb0ff59906db564d40f1857.xml" rel="search" title="Booking.com online hotelreserveringen" type="application/opensearchdescription+xml"/>
# <link href="https://plus.google.com/105443419075154950489" rel="publisher"/>
# <script nonce="K1kLW5Ph1ocREa4">
# /*
# */
# (function avoidingXSSviaLocationHash() {
# var location = window.location,
# hash = location.hash,
# xss = /[<>'"]/;
# if (
# xss.test( decodeURIComponent( hash ) ) ||
# xss.test( hash )
# ) {
# location.hash = '';
# }
# })();
# document.documentElement.className = document.documentElement.className.replace('noJS', '') + ' hasJS';
# var b_experiments = {}, WIDTH, B = window.booking = {
# _onfly: [], // "on the fly" functions, will be executed as soon as external js files were loaded
# devTools: {
# trackedExperiments: []
# },
# user: {
# },
# env : {
# isRetina : window.devicePixelRatio > 1,
# "b_gtt": 'dLYAeZFVJfNTBBSLFYYTObZRJfOfdAccOBFPbC',
# "b_action" : 'city',
# "b_secure_domain" : 'https://secure.booking.com',
# "b_site_type" : 'www',
# "b_site_type_id": '1',
# "b_calendar2" : '1',
# /*
# */
# "b_partner_channel_id": '3',
# "b_bookings_owned": '1',
# "b_google_maps_key_params" : 'true&indexing=true',
# "b_lang" : 'nl',
# "b_has_valid_dates": 0,
# "b_countrycode" : 'de',
# "b_guest_country" : 'nl',
# "b_locale" : 'nl-nl',
# "b_lang_for_url" : 'nl',
# "b_this_urchin" : '/city/de/hamburg.nl.html&amp;',
# "b_flag_to_suggest" : 'nl',
# "b_companyname" : 'Booking.com',
# "b_partner_vertical" : 'channel_direct',
# b_date_format: {"day_month_year_time_before":"vóór {day_name} {month_name} {year} om {time}","day_month_year":"{day_name} {month_name} {full_year}","date_with_weekday_from":"{weekday_from} {day_of_month} {month_name_from} {full_year}","ux_day_month_on":"op {day_2} {month_2}","ux_day_month":"","short_date_with_weekday_without_year":"{short_weekday} {day_of_month} {short_month_name}","month_name_only":"{month_name_nom}","date_with_weekday_time_at":"date_with_weekday_time_at","in_month_with_year":"in {month_name_in} {full_year}","day_short_month_year_until":"tot {day_name} {short_month_name} {full_year}","day_month_on":"op {day_name} {month_name}","short_weekday_only":"{short_weekday}","day_short_month":"{day_name} {short_month_name}","day_month_year_other":"van {day_name} {month_name} {full_year}","day_month_until":"tot {day_name} {month_name}","day_short_month_year_time_between":"{day_of_month} {short_month_name} {full_year}, {time}-{time_until}","day_short_month_from":"vanaf {day_name} {short_month_name}","date_with_short_weekday_with_year":"{short_weekday} {day_of_month} {month_name} {full_year}","date_with_short_weekday_without_year":"{short_weekday} {day_of_month} {month_name}","numeric_date_range_both_years":"{day_of_month}/{month}/{full_year} - {day_of_month_until}/{month_until}/{full_year_until}","day_short_month_year_from":"vanaf {day_name} {short_month_name} {full_year}","date_with_weekday_with_markers":"{weekday} {begin_marker}{day_of_month} {month_name}{end_marker} {full_year}","numeric_day_month_year":"{day_name_0}-{month_name_0}-{full_year}","day_month_year_until":"tot {day_name} {month_name} {full_year}","day_short_month_year_on":"op {day_name} {short_month_name} {full_year}","day_of_month_only":"{day_of_month}","day_month":"{day_name} {month_name}","date_with_weekday_time_until":"{weekday} {begin_marker}{day_of_month} {month_name}{end_marker} {full_year} tot {time}","day_short_month_year_other":"van {day_name} {short_month_name} {full_year}","day_month_year_on":"op {day_name} {month_name} {full_year}","numeric_day_month_year_on":"op {day_name_0}-{month_name_0}-{full_year}","date_without_year":"{day_of_month} {month_name}","day_short_month_year_between":"{day_of_month} {short_month_name} {full_year} - {day_of_month_until} {short_month_name_until} {full_year_until}","day_short_month_until":"tot {day_name} {short_month_name}","short_date_without_year":"{day_of_month} {short_month_name}","short_date_with_weekday":"{short_weekday} {day_of_month} {short_month_name} {full_year}","numeric_date_range":"{day_of_month}/{month} - {day_of_month_until}/{month_until}","date_with_weekday_time_from":"{weekday} {begin_marker}{day_of_month} {month_name}{end_marker} {full_year} vanaf {time}","date_with_weekday_time_from_until":"{weekday} {begin_marker}{day_of_month} {month_name}{end_marker} {full_year} van {time} tot {time_until}","day_short_month_year_time":"{day_of_month} {short_month_name} {full_year}, {time}","day_short_month_time":"{day_of_month} {short_month_name}, {time}","numeric_day_month_year_between":"van {day_name_0}-{month_name_0}-{full_year} t/m {day_name_0_until}-{month_name_0_until}-{full_year_until}","from_month_with_year":"sinds {month_name_from} {full_year}","day_short_month_on":"op {day_name} {short_month_name}","short_month_with_year":"{short_month_name} {full_year}","day_short_month_year":"{day_name} {short_month_name} {full_year}","short_date_without_year_range":"{day_of_month} {short_month_name} - {day_of_month_until} {short_month_name_until}","short_month_only":"{short_month_name}","day_short_month_between":"{day_of_month} {short_month_name} - {day_of_month_until} {short_month_name_until}","long_date_range_both_years":"{day_of_month} {month_name} {full_year} - {day_of_month_until} {month_name_until} {full_year_until}","numeric_day_month_year_from":"vanaf {day_name_0}-{month_name_0}-{full_year}","date_with_weekday":"{weekday} {day_of_month} {month_name} {full_year}","day_month_year_from":"vanaf {day_name} {mo ...
# b_month_for_formatted_date: {"1":{"name_in":"januari","genitive_lc":"januari","name_with_year_only":"januari","name_uc":"januari","name_only":"januari","name_from":"januari","short_name_uc":"januari","name_lc":"januari","in_month_lc":"in januari","genitive_uc":"Januari","to_month_lc":"tot januari","name_other":"januari","name_to":"januari","month_2":"januari","name":"januari","name_def_article_uc":"januari","on_day_month":"01","name_def_article_lc":"januari","short_name":"jan","month_1":"januari","day_to":"januari"},"10":{"name_in":"oktober","genitive_lc":"oktober","name_uc":"oktober","name_with_year_only":"oktober","name_only":"oktober","name_from":"oktober","short_name_uc":"oktober","name_lc":"oktober","in_month_lc":"in oktober","genitive_uc":"Oktober","to_month_lc":"tot oktober","name_other":"oktober","name_to":"oktober","month_2":"oktober","name":"oktober","name_def_article_uc":"oktober","on_day_month":"10","short_name":"okt","name_def_article_lc":"oktober","month_1":"oktober"},"11":{"name_in":"november","genitive_lc":"november","name_uc":"november","name_with_year_only":"november","name_only":"november","name_from":"november","short_name_uc":"november","name_lc":"november","in_month_lc":"in november","genitive_uc":"November","to_month_lc":"tot november","name_other":"november","name_to":"november","month_2":"november","name_def_article_uc":"november","name":"november","on_day_month":"11","name_def_article_lc":"november","short_name":"nov","month_1":"november"},"12":{"genitive_lc":"december","name_uc":"december","name_with_year_only":"december","name_in":"december","name_lc":"december","in_month_lc":"in december","name_only":"december","name_from":"december","short_name_uc":"december","genitive_uc":"December","to_month_lc":"tot december","name_other":"december","name":"december","name_def_article_uc":"december","name_to":"december","month_2":"december","month_1":"december","on_day_month":"12","short_name":"dec","name_def_article_lc":"december"},"2":{"short_name_uc":"februari","name_from":"februari","name_only":"februari","in_month_lc":"in februari","name_lc":"februari","name_in":"februari","name_with_year_only":"februari","name_uc":"februari","genitive_lc":"februari","genitive_uc":"Februari","name_other":"februari","to_month_lc":"tot februari","name_def_article_lc":"februari","short_name":"feb","on_day_month":"02","day_to":"februari","month_1":"februari","name_to":"februari","month_2":"februari","name_def_article_uc":"februari","name":"februari"},"3":{"to_month_lc":"tot maart","name_other":"maart","month_2":"maart","name_to":"maart","name_def_article_uc":"maart","name":"maart","short_name":"mrt","name_def_article_lc":"maart","on_day_month":"03","month_1":"maart","day_to":"maart","name_in":"maart","name_with_year_only":"maart","name_uc":"maart","genitive_lc":"maart","short_name_uc":"maart","name_from":"maart","name_only":"maart","in_month_lc":"in maart","name_lc":"maart","genitive_uc":"Maart"},"4":{"short_name":"apr","name_def_article_lc":"april","on_day_month":"04","month_1":"april","month_2":"april","name_to":"april","name_def_article_uc":"april","name":"april","name_other":"april","to_month_lc":"tot april","genitive_uc":"April","short_name_uc":"april","name_from":"april","name_only":"april","in_month_lc":"in april","name_lc":"april","name_in":"april","name_uc":"april","name_with_year_only":"april","genitive_lc":"april"},"5":{"to_month_lc":"tot mei","name_other":"mei","name_to":"mei","month_2":"mei","name_def_article_uc":"mei","name":"mei","short_name":"mei","name_def_article_lc":"mei","on_day_month":"05","month_1":"mei","name_in":"mei","name_uc":"mei","name_with_year_only":"mei","genitive_lc":"mei","name_from":"mei","short_name_uc":"mei","name_only":"mei","in_month_lc":"in mei","name_lc":"mei","genitive_uc":"Mei"},"6":{"in_month_lc":"in juni","name_lc":"juni","short_name_uc":"juni","name_from":"juni","name_only":"juni","name_uc":"juni","name_with_year_only":"juni","genitive_lc":"juni","name_in":"juni","genitive_uc":"Juni ...
# b_weekday_formatted_date: {"1":{"short_uc":"Ma","name_uc":"Maandag","name_lc":"maandag","shortest":"ma","name_other":"maandag","name_from":"maandag","name_on":"maandag","name":"maandag","name_to":"maandag","short":"ma","name_other_uc":"Maandag"},"2":{"name_from":"dinsdag","name_other":"dinsdag","shortest":"di","name_lc":"dinsdag","short_uc":"Di","name_uc":"Dinsdag","name_other_uc":"Dinsdag","short":"di","name_to":"dinsdag","name":"dinsdag","name_on":"dinsdag"},"3":{"short":"wo","name_other_uc":"Woensdag","name_on":"woensdag","name":"woensdag","name_to":"woensdag","name_lc":"woensdag","shortest":"wo","name_from":"woensdag","name_other":"woensdag","name_uc":"Woensdag","short_uc":"Wo"},"4":{"short_uc":"Do","name_uc":"Donderdag","shortest":"do","name_lc":"donderdag","name_other":"donderdag","name_from":"donderdag","name":"donderdag","name_on":"donderdag","name_to":"donderdag","name_other_uc":"Donderdag","short":"do"},"5":{"shortest":"vr","name_lc":"vrijdag","name_other":"vrijdag","name_from":"vrijdag","short_uc":"Vr","name_uc":"Vrijdag","name_other_uc":"Vrijdag","short":"vr","name":"vrijdag","name_on":"vrijdag","name_to":"vrijdag"},"6":{"name_uc":"Zaterdag","short_uc":"Za","name_other":"zaterdag","name_from":"zaterdag","shortest":"za","name_lc":"zaterdag","name_to":"zaterdag","name":"zaterdag","name_on":"zaterdag","name_other_uc":"Zaterdag","short":"za"},"7":{"short":"zo","name_other_uc":"Zondag","name_on":"zondag","name":"zondag","name_to":"zondag","name_lc":"zondag","shortest":"zo","name_from":"zondag","name_other":"zondag","short_uc":"Zo","name_uc":"Zondag"},"8":{"name_uc":"name_uc","short_uc":"short_uc","name_other":"name_other","name_from":"name_from","name_lc":"every day","shortest":"shortest","name_to":"name_to","name_on":"name_on","name":"Elke dag","short":"short","name_other_uc":"name_other_uc"}},
# b_time_format: {"AM_symbol":{"name":"AM"},"PM_symbol":{"name":"PM"},"time":{"name":"{hour_24h}:{minutes}"}},
# "b_protocol": 'https',
# b01: 1,
# auth_level : "0",
# b_user_auth_level_is_none : 1,
# b_check_ot_consent : 1,
# bui: {
# color: {
# bui_color_grayscale_dark: "#333333",
# bui_color_grayscale: "#6B6B6B",
# bui_color_grayscale_light: "#BDBDBD",
# bui_color_grayscale_lighter: "#E6E6E6",
# bui_color_grayscale_lightest: "#F5F5F5",
# bui_color_primary_dark: "#00224F",
# bui_color_primary: "#003580",
# bui_color_primary_light: "#BAD4F7",
# bui_color_primary_lighter: "#EBF3FF",
# bui_color_primary_lightest: "#FAFCFF",
# bui_color_complement_dark: "#CD8900",
# bui_color_complement: "#FEBB02",
# bui_color_complement_light: "#FFE08A",
# bui_color_complement_lighter: "#FDF4D8",
# bui_color_complement_lightest: "#FEFBF0",
# bui_color_callout_dark: "#BC5B01",
# bui_color_callout: "#FF8000",
# bui_color_callout_light: "#FFC489",
# bui_color_callout_lighter: "#FFF0E0",
# bui_color_callout_lightest: "#FFF8F0",
# bui_color_destructive_dark: "#A30000",
# bui_color_destructive: "#CC0000",
# bui_color_destructive_light: "#FCB4B4",
# bui_color_destructive_lighter: "#FFEBEB",
# bui_color_destructive_lightest: "#FFF0F0",
# bui_color_constructive_dark: "#006607",
# bui_color_constructive: "#008009",
# bui_color_constructive_light: "#97E59C",
# bui_color_constructive_lighter: "#E7FDE9",
# bui_color_constructive_lightest: "#F1FEF2",
# bui_color_action: "#0071C2",
# bui_color_white: "#FFFFFF",
# bui_color_black: "#000000"
# }
# },
# bb: {
# ibb: "",
# uibb: "",
# ibbta: "",
# itp: "",
# iuibb: "",
# bme: "",
# euibb: "",
# tp: ""
# },
# b_growls_close_fast: 1,
# fe_enable_login_with_phone_number: 1,
# asyncLoader: {
# async_assistant_entrypoint_css: 'https://cf.bstatic.com/static/css/assistant_entrypoint_cloudfront_sd.iq_ltr/3465a3f95529f91b80ca52a415d697689e98708b.css',
# async_assistant_entrypoint_js: 'https://cf.bstatic.com/static/js/assistant_entrypoint_cloudfront_sd/eedfd8b3b2afb306a8e93fc59a4ca677762d4844.js',
# async_atlas_places_js: 'https://cf.bstatic.com/static/js/atlas_places_async_cloudfront_sd/a1d64a938e156acd9f00c4ffd8f9422a0d4ca85c.js',
# async_atlas_v2_cn_js: 'https://cf.bstatic.com/static/js/async_atlas_v2_cn_cloudfront_sd/d5757834d3a448085854c0ecbe7eb37b325895ee.js',
# async_atlas_v2_non_cn_js: 'https://cf.bstatic.com/static/js/async_atlas_v2_non_cn_cloudfront_sd/f30a916b8c32231e0dedb22ca162ca739ecbe502.js',
# image_gallery_js: 'https://cf.bstatic.com/static/js/ski_lp_overview_panel_cloudfront_sd/9d8e7cfd33a37ffb15285d98f6970024f06cf36d.js',
# image_gallery_css: 'https://cf.bstatic.com/static/css/ski_lp_overview_panel_cloudfront_sd.iq_ltr/e905a114a7e2a2092dfa73ce9ac18c326a2d9a25.css',
# async_lists_js: 'https://cf.bstatic.com/static/js/async_lists_cloudfront_sd/c9eb5d202a4467feaf00668360ee36fc4b47da0e.js',
# async_landing_pages_atlas_map_css: 'https://cf.bstatic.com/static/css/async_landing_pages_atlas_map_cloudfront_sd/283bcd9707fffcdd3769f01fcf002b75f1cad401.css',
# async_landing_pages_atlas_map_js: 'https://cf.bstatic.com/static/js/async_landing_pages_atlas_map_cloudfront_sd/1bda38ef443881269dc53aaf86cb55ec608db345.js',
# async_wpm_overlay_css: 'https://cf.bstatic.com/static/css/async_wpm_overlay_assets_cloudfront_sd.iq_ltr/abb304bf3600a5cf5f7406a27f042cf1ce2429b1.css',
# async_wpm_overlay_js: 'https://cf.bstatic.com/static/js/async_wpm_overlay_assets_cloudfront_sd/a7aad63951a15d950d5c01ef6635e8bd994e65a7.js',
# empty: ''
# },
# fe_enable_fps_goal_with_value: 1,
# b_email_validation_regex : /^([\w-\.\+]+@([\w-]+\.)+[\w-]{2,14})?$/,
# b_domain_end : '.booking.com',
# b_original_url : 'https:&#47;&#47;www.booking.com&#47;city&#47;de&#47;hamburg.nl.html',
# b_this_url : '/city/de/hamburg.nl.html',
# b_this_url_without_lang : '/city/de/hamburg.html',
# b_referrer : '',
# b_acc_type : '',
# b_req_login: '',
# jst : {'loading': true},
# keep_day_month: true,
# b_timestamp : 1626794920,
# scripts_tracking : {
# },
# enable_scripts_tracking : 1,
# b_ufi : '-1785434',
# "setvar_affiliate_is_bookings2" : 1,
# transl_close_x : 'Sluiten',
# transl_checkin_title: 'Incheckdatum',
# transl_checkout_title: 'Uitcheckdatum',
# browser_lang: '',
# b_hijri_calendar_available: false,
# b_aid: '304142',
# b_label: 'gen000nr-10CAMoOzjWAkgcWARoqQGIAQGYATO4AQXIAR7YAQPoAQH4AQGIAgGoAgG4AqjX24cGwAIB0gIkZDQxOWY1MDYtMDE4ZC00ZmE5LTkxZDItYjBmYTE4MjExOTkx2AIB4AIB',
# b_sid: '',
# b_dest_id: '-1785434',
# ip_country: 'nl',
# country_currency: 'EUR',
# b_selected_currency: 'EUR',
# b_selected_language: 'nl',
# b_selected_language_country_flag: 'nl',
# pageview_id: 'bd656cd4835d01ab',
# aid: '304142',
# b_csrf_token: '6CP3YAAAAAA=eKLA-gP81lQCjxq0spRXlY9w6kJlY7VaTH5J-x4ae8-vB1vwhQoDZEPL44BxOcVl6TOEkxJbQj75jKhikmMrP19MDP-I24va9uixzHBQa4qoR7e_ohL0Glmbe1EJA02AXEVHz8gfD3yb5PNXrj8X4AJYPERbzsjMQvXIv8mbjjdrNOkJAFAYrY0T-_9qYc5lyv8rqSXr9-j7dcGq',
# b_show_user_accounts_features: 1,
# b_browser: 'bot',
# et_debug_level: '0',
# icons: '/static/img',
# b_static_images: 'https://cf.bstatic.com/images/',
# b_currency_url: '/general.nl.html;tmpl=currency_foldout;cur_currency=EUR;cc1=de',
# b_languages_url: '/general.nl.html;tmpl=language_foldout',
# b_weekdays: [
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('1'),
# "name": 'maandag',
# "short": 'ma',
# "shorter": 'ma',
# "shortest": 'ma'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('2'),
# "name": 'dinsdag',
# "short": 'di',
# "shorter": 'di',
# "shortest": 'di'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('3'),
# "name": 'woensdag',
# "short": 'wo',
# "shorter": 'wo',
# "shortest": 'wo'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('4'),
# "name": 'donderdag',
# "short": 'do',
# "shorter": 'do',
# "shortest": 'do'},
# {"b_is_weekend": parseInt( '' ),
# "b_number": parseInt('5'),
# "name": 'vrijdag',
# "short": 'vr',
# "shorter": 'vr',
# "shortest": 'vr'},
# {"b_is_weekend": parseInt( '1' ),
# "b_number": parseInt('6'),
# "name": 'zaterdag',
# "short": 'za',
# "shorter": 'za',
# "shortest": 'za'},
# {"b_is_weekend": parseInt( '1' ),
# "b_number": parseInt('7'),
# "name": 'zondag',
# "short": 'zo',
# "shorter": 'zo',
# "shortest": 'zo'},
# {}],
# b_group: [],
# b_simple_weekdays: ['ma','di','wo','do','vr','za','zo'],
# b_simple_weekdays_for_js: ['ma','di','wo','do','vr','za','zo'],
# b_long_weekdays: ['maandag','dinsdag','woensdag','donderdag','vrijdag','zaterdag','zondag'],
# b_short_months: ['januari','februari','maart','april','mei','juni','juli','augustus','september','oktober','november','december'],
# b_short_months_abbr: ['jan','feb','mrt','apr','mei','jun','jul','aug','sep','okt','nov','dec'],
# b_year_months: {
# '2021-7': {'name': 'juli 2021' },
# '2021-8': {'name': 'augustus 2021' },
# '2021-9': {'name': 'september 2021' },
# '2021-10': {'name': 'oktober 2021' },
# '2021-11': {'name': 'november 2021' },
# '2021-12': {'name': 'december 2021' },
# '2022-1': {'name': 'januari 2022' },
# '2022-2': {'name': 'februari 2022' },
# '2022-3': {'name': 'maart 2022' },
# '2022-4': {'name': 'april 2022' },
# '2022-5': {'name': 'mei 2022' },
# '2022-6': {'name': 'juni 2022' },
# '2022-7': {'name': 'juli 2022' },
# '2022-8': {'name': 'augustus 2022' },
# '2022-9': {'name': 'september 2022' },
# '2022-10': {'name': 'oktober 2022' }
# },
# b_is_landing_page : 1,
# b_is_landing : 1,
# b_user_auth_level_is_none: 1,
# b_is_fb_safe: 1,
# b_is_app: 1,
# first_page_of_results: true,
# b_partner_id: '1',
# b_is_destination_finder_supported: 0,
# b_is_dsf: 0,
# b_pr_param: '',
# /*
# */
# feature_profile_split_sb_checkbox: 1,
# inandaround_more: "Meer",
# b_signup_iframe_url: 'https://secure.booking.com' + '/login.html?tmpl=profile/signup_after_subscribe' + '&lang=nl' ,
# b_exclude_lang_firstname: 0,
# view_prices_enter_dates: 'Selecteer uw aankomst- en vertrekdatum om prijzen en beschikbaarheid te bekijken.',
# autocomplete_categories: {
# city: 'Steden',
# region: 'Regio\'s',
# airport: 'Luchthavens',
# hotel: 'Hotels',
# landmark: 'Bezienswaardigheden',
# country: 'Landen',
# district: 'Wijken',
# theme: 'Thema\'s'
# },
# autocomplete_skip_suggestions: 'Zoek naar meer alternatieven',
# autocomplete_counter_label: 'Accommodaties in de buurt',
# autocomplete : {
# property_nearby: '1 accommodatie in de buurt',
# properties_nearby: ' accommodaties in de buurt',
# hotel: 'accommodatie',
# hotels: 'accommodaties',
# hotels_nearby: 'Accommodaties in de buurt'
# },
# lists: {
# collection: [
# {
# id: "0",
# name: "Mijn volgende reis",
# hotels_count: "0"
# }
# ]
# },
# touch_os: false,
# calendar_days_allowed_number: 345,
# b_search_max_months: 16,
# b_run_ge_new_newsletter_login: 1,
# b_password_strength_msg: ['Niet lang genoeg','Zwak','Redelijk','Goed','Sterk','Zeer sterk'],
# b_passwd_min_length_error: 'Het wachtwoord moet uit minimaal 8 karakters bestaan',
# b_password_must_be_numeric: 'De pincode van je reservering bestaat uit 4 cijfers. Probeer het nog eens',
# b_bkng_nr_must_be_numeric: 'Je boekingsnummer bestaat uit 9 cijfers. Probeer het nog eens',
# b_blank_numeric_pin: 'Vul de pincode van je reservering in',
# b_blank_bkng_nr: 'Vul je boekingsnummer in',
# password_cant_be_username: 'Uw wachtwoord kan niet hetzelfde zijn als uw e-mailadres',
# b_show_passwd: 'Wachtwoord bekijken',
# b_passwd_tooltip: 'Hoofdletters, cijfers en bijzondere tekens verhogen de veiligheid van uw wachtwoord',
# account_error_add_password: 'Voeg een wachtwoord toe',
# password_needs_8: 'Het wachtwoord moet uit minimaal 8 karakters bestaan',
# error_sign_up_password_email_combo_01: 'Check uw e-mailadres of wachtwoord en probeer het opnieuw.',
# social_plugins_footer: 1,
# b_lazy_load_print_css: 1,
# print_css_href: 'https://cf.bstatic.com/static/css/print/0cc4ce4b7108d42a9f293fc9b654f749d84ba4eb.css',
# 'component/dropdown-onload-shower/header_signin_prompt' : {
# b_action: "city"
# ,can_redirect: 1
# ,redirect_uri: "https://account.booking.com/auth/oauth2?aid=304142&response_type=code&lang=nl&bkng_action=city&dt=1626794921&redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&client_id=vO1Kblk7xX9tUn2cpZLS&state=UtgBjLbVrbNGXySu6gFxMp42ZwROAQyNBELjWRx7uAbg9ej9JxaFDrWtKi9mVbqdyqyxOx_SN73ZpPPC7TD0fD8Pnu4PcbuFU-jsOEW1iaBl2fs9lxVtNqlWGDQ5OwEQ6gI3-Z1i-pZg4UePwweud2xlPduf5mW57hihuD0IoCioh8yJGAG3AHiYlSlbsg-ZSuEvl3PQVIofZK-mRQZ6H-fjFZi4fqbRoApEgZzsm8qbRyESyHw7v_393Oq4Wa3KNdIu5dF3xhyhOfWnABhsdsTX85mHkx223Il9"
# },
# b_hostname_signup: "www.booking.com",
# b_nonsecure_hostname: "https://www.booking.com",
# b_nonsecure_hostname_signup: "https://www.booking.com",
# b_fd_searchresults_url_signup: "",
# translation_customer_service_which_booking_no_specific: 'Geen specifieke reservering',
# stored_past_and_upcoming_bookings: [
# ],
# global_translation_tags: {"nbsp":"&nbsp;","one_dot_leader":"\u2024","line_break":"\u003cbr\u003e","zwsp":"\u200b","lrm":"\u200e","rlm":"\u200f"},
# b_rackrates_monitoring_running: true,
# b_wishlist_referrer : '',
# b_reg_user_last_used_wishlist: "",
# b_reg_user_wishlist_remaining: 1,
# is_user_center_bar: 1,
# b_site_experiment_user_center_bar: 1,
# b_reg_user_is_genius : "",
# profile_menu: {
# b_user_auth_level: 0,
# b_domain_for_app: "https://www.booking.com",
# b_query_params_with_lang_no_ext: "",
# b_action: "city",
# b_site_info: {"is_bookings_owned":1,"is_iam_auth_allowed":1},
# b_site_type: "www",
# b_companyname: "Booking.com",
# b_reg_user_full_name: "",
# b_is_genius_branded: "0",
# b_reg_user_is_genius: "",
# b_genius_dashboard_expiry_destfinder_url: "https://www.booking.com/destinationfinderdeals.nl.html;genius_deals_mode=1&genius_next_weekend=1",
# b_run_bb_pb_reports: "",
# b_bwallet_has_wallet: 0,
# b_bwallet_currency_html: "",
# b_bwallet_total_balance_p: "",
# b_bwallet_has_credit: "",
# b_bwallet_total_balance_euro: "",
# b_bwallet_hide_badge_profile_dropdown: "",
# b_rewards_has_reward: 0,
# b_reg_user_last_used_wishlist: "",
# b_genius_product_page_url: "https://www.booking.com/genius.nl.html",
# b_reg_user_five_bookings_challenge: "",
# b_reg_user_detail_name_email_hash: "",
# b_user_is_grap_eligible: "",
# b_grap_remove_raf_checks: 1,
# b_is_bbtool_admin: "",
# b_is_bbtool_user: "",
# fe_bbtool_permission_is_connected_to_bbtool: "",
# fe_this_url_travel_purpose_business: "https://secure.booking.com/company/search.nl.html",
# fe_this_url_travel_purpose_leisure: "https://www.booking.com/index.nl.html",
# fe_reservations_url_travel_purpose_business: "https://secure.booking.com/company/reservations.nl.html",
# fe_reservations_url_travel_purpose_leisure: "https://secure.booking.com/myreservations.nl.html",
# fe_my_settings_url: "https://account.booking.com/oauth2/authorize?aid=304142;client_id=d1cDdLj40ACItEtxJLTo;redirect_uri=https%3A%2F%2Faccount.booking.com%2Fsettings%2Foauth_callback;response_type=code;state=eyJteXNldHRpbmdzX3BhdGgiOiIvbXlzZXR0aW5ncyIsImFpZCI6MzA0MTQyfQ",
# fe_my_settings_url_travel_purpose_business: "https://secure.booking.com/mysettings.nl.html",
# fe_my_settings_url_travel_purpose_leisure: "https://secure.booking.com/mysettings.nl.html",
# fe_bbtool_can_see_tool_promos: "1",
# fe_bbtool_can_see_tool_promos: "1",
# fe_bbtool_blackout_user_company: "",
# fe_bbtool_redirect_personal_to_index: 1,
# b_reg_user_company_name: "",
# b_reg_user_company_name_escaped: "",
# b_reg_user_companyjoin_url: "",
# b_bbtool_product_page_url: "https://www.booking.com/business.nl.html",
# b_is_ie7: "",
# b_this_url: "/city/de/hamburg.nl.html",
# b_lang_for_url: "nl",
# b_secure_hostname: "https://secure.booking.com",
# b_nonsecure_hostname: "https://www.booking.com",
# b_query_params_with_lang: ".nl.html",
# b_query_params_with_lang_no_ext: "",
# b_query_params_delimiter: ";",
# b_reg_user_detail_dashboard_url: "",
# b_is_reg_user_city_guide_in_lang_available: "0",
# b_aspiring_user_fifth_booking_ufi : "",
# b_reg_user_aspiring_data: "",
# b_dummy_var_for_trailing_comma: false,
# b_ip_country: "",
# b_guest_country: "nl",
# b_raf_multiple_campaigns: true,
# b_agent_is_no_robot: "",
# b_page_name : "city",
# b_landingpage_theme_type: "",
# b_brewards_account_details: "",
# b_upcoming_rewards: "",
# b_rewards_reminder_is_on: 1,
# fe_rewards__game_over: "1",
# loyalty_program_rules: "",
# loyalty_program_status: "",
# loyalty_program_bonus_url: "",
# b_brewards_loyalty_program_account_type: "",
# b_user_has_mobile_app: "",
# b_aid: 304142,
# b_label: "gen000nr-10CAMoOzjWAkgcWARoqQGIAQGYATO4AQXIAR7YAQPoAQH4AQGIAgGoAgG4AqjX24cGwAIB0gIkZDQxOWY1MDYtMDE4ZC00ZmE5LTkxZDItYjBmYTE4MjExOTkx2AIB4AIB",
# fe_show_travel_communities_menu_item: 1,
# fe_user_can_see_company_reservations: null,
# b_oauth_client_id: "vO1Kblk7xX9tUn2cpZLS",
# b_sso_logout_url: "",
# b_sso_logout_callback_url: "",
# fe_sso_logout_state: "",
# fe_blackout_mydashboard: "",
# fe_user_menu_aspiring_genius_link: false
# },
# accounting_config: {"html_symbol":{"EUR":"&#x20AC;","PLN":"z&#x0142;","IDR":"Rp","TRY":"TL","ILS":"&#x20AA;","CLP":"CL$","XPF":"CFP","JPY":"&#165;","USD":"US$","RON":"lei","CZK":"K&#269;","INR":"Rs.","GBP":"&#163;","BRL":"R$","ARS":"AR$","HKD":"HK$","SGD":"S$","PHP":"&#8369;"},"decimal_separator":{"default":","},"group_separator":{"default":"."},"symbol_position":{"default":"before","CZK":"after","PLN":"after","RON":"after"},"num_decimals":{"BIF":0,"AFA":0,"GNF":0,"TJR":0,"LYD":3,"RWF":0,"MGA":0,"LAK":0,"IDR":0,"KWD":3,"VUV":0,"DJF":0,"CLP":0,"KRW":0,"XPF":0,"ISK":0,"UGX":0,"BYR":0,"XAF":0,"JOD":3,"KMF":0,"default":2,"PYG":0,"VND":0,"BHD":3,"COP":0,"ECS":0,"TND":3,"HUF":0,"RUB":0,"XOF":0,"OMR":3,"MZM":0,"TMM":0,"IQD":3,"TWD":0,"JPY":0},"currency_separator":{"JPY":"","default":"&nbsp;","GBP":"","USD":""}},
# distance_config: "metric",
# b_run_tfl_move_away_from_lightbox: true,
# b_wishlist_singlepage_url: 'https://secure.booking.com/mywishlist.nl.html',
# is_listview_page: true,
# b_this_weekend_checkin: "",
# b_this_weekend_checkout: "",
# b_next_weekend_checkin: "",
# b_next_weekend_checkout: "",
# b_official_continent: "",
# b_deals_continents : "",
# b_messenger_url: '',
# b_open_messenger: false,
# b_is_asian_user: '',
# b_days_to_checkin: '',
# b_extra_ajax_headers: {},
# et_debug_level: '0',
# wl_squeak: {
# open_wishlist_from_profile: 'ZQafLebbMTSWEEdC',
# },
# trip_types_squeaks : {
# dummyvar:false
# },
# trackExperiment : function () {},
# "error" : {}
# },
# ensureNamespaceExists: function (namespaceString) {
# if (!booking[namespaceString]) {
# booking[namespaceString] = {};
# }
# }, hotel: {}, experiments: {}, startup: {}, experiments_load: {}, startup_load: {}, promotions: {}, timestamp: new Date()};
# function Tip() {};
# (function (scope) {
# booking.env.b_sb_autocomplete_predictions_url = '/autocomplete_csrf';
# booking.env.b_sb_autocomplete_predictions_method = 'GET';
# booking.env.b_sb_googleplaces_carrier_url = 'https://carrier.booking.com/google/places/webautocompletesimple';
# booking.env.b_sb_googleplaces_carrier_method = 'POST';
# var params = scope.search_autocomplete_params = {};
# params.v = '1';
# params.lang = 'nl';
# params.sid = '';
# params.aid = '304142';
# params.pid = 'bd656cd4835d01ab';
# params.stype = '1';
# params.src = 'city';
# params.eb = '0';
# params.e_obj_labels = '1';
# params.context_dest_type = 'city';
# params.context_dest_id = '-1785434';
# params.e_tclm = 1;
# params.add_themes = '1';
# params.themes_match_start = '1';
# params.include_synonyms = '1';
# }(window.autocomplete_vars || booking.env));
# </script>
# <script nonce="K1kLW5Ph1ocREa4">var _gaq = _gaq || [];</script>
# <!--[if IE]> <script nonce="K1kLW5Ph1ocREa4"> document.createElement('time'); </script> <![endif]-->
# <script nonce="K1kLW5Ph1ocREa4">
# ...
# <path d="M187.08 25.067C187.06 25.088 184.38 27.915 180.87 27.915C177.66 27.915 174.42 25.941 174.42 21.538C174.42 17.73 176.93 15.071 180.53 15.071C181.7 15.071 183.02 15.492 183.23 16.198L183.26 16.318C183.74 17.919 185.19 18.001 185.47 18.001L188.88 18.005V15.021C188.88 11.085 183.89 9.65698 180.53 9.65698C173.35 9.65698 168.14 14.674 168.14 21.584C168.14 28.489 173.29 33.502 180.4 33.502C186.56 33.502 189.91 29.434 189.94 29.391L190.12 29.172L187.43 24.685L187.08 25.067ZM244.43 9.65698C241.73 9.65698 239.25 10.927 237.58 13.05L237.11 13.651L236.74 12.979C235.53 10.776 233.46 9.65698 230.57 9.65698C227.55 9.65698 225.53 11.35 224.58 12.358L223.97 13.024L223.73 12.144C223.39 10.877 222.26 10.178 220.56 10.178H218.06L218.04 32.984H224.01V22.917C224.01 22.036 224.12 21.163 224.34 20.248C224.93 17.816 226.56 15.202 229.3 15.462C230.99 15.626 231.81 16.936 231.81 19.466V32.984H237.44V22.917C237.44 21.813 237.55 20.99 237.79 20.162C238.3 17.842 240.37 15.459 243.02 15.459C244.93 15.459 245.93 16.545 245.93 19.466V29.649C245.93 31.954 247.28 32.984 249.57 32.984H251.99L252 18.424C252 12.607 249.45 9.65698 244.43 9.65698V9.65698ZM203.66 10.043C196.76 10.043 191.35 15.031 191.35 21.898C191.35 28.765 196.76 33.754 203.66 33.754C210.58 33.754 215.61 28.765 215.61 21.898C215.61 15.031 210.58 10.043 203.66 10.043V10.043ZM158.31 29.446C158.31 27.34 160 25.636 162.09 25.636C164.18 25.636 165.88 27.34 165.88 29.446C165.88 31.548 164.18 33.254 162.09 33.254C160 33.254 158.31 31.548 158.31 29.446ZM203.66 28.209C200.4 28.209 198.13 25.611 198.13 21.898C198.13 18.186 200.4 15.59 203.66 15.59C206.93 15.59 209.23 18.186 209.23 21.898C209.23 25.671 206.99 28.209 203.66 28.209Z" fill="#0896FF"></path>
# </svg>
# <svg aria-hidden="true" class="bk-icon -iconset-close" focusable="false" height="128" role="presentation" style="display:none;" viewbox="0 0 128 128" width="128"><path d="M69.7 64l33.1-33.2a4 4 0 0 0-5.6-5.6L64 58.3 30.8 25.2a4 4 0 1 0-5.6 5.6L58.3 64 25.2 97.2a4 4 0 1 0 5.6 5.6L64 69.7l33.2 33.1a4 4 0 0 0 5.6-5.6z"></path></svg>
# <div class="iam_account_access">
# <div class="iam_card iam_login_form">
# <div class="iam_login_text iam_login_text--header">
# Log in om verder te gaan
# </div>
# <a class="iam_login_btn--email bui-button bui-button--large bui-button--wide bui-spacer" data-bui-component="Button" href="https://account.booking.com/auth/oauth2?response_type=code&amp;lang=nl&amp;aid=304142&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;client_id=vO1Kblk7xX9tUn2cpZLS&amp;state=UsMBjLbVrbNGXyS_PoM5BegGOmXVqVlBCMI_Pt3XWdWXAvGVoNjn1O71RzixTBd8B3JwFIXYBjbQP2rYSfBL9iXDwcc8feLTM78joVSqXIWvJkDMpvQIDP-0zpUNOCg42OboScrvnYb6yHoE7fmX7o29F3IvgR5WajQRPAI-G0kqgGIyefxlXWtVDq0eUZa0EnBZIHNpJ-KU94X1-UTTh8bPs7rklGQXtv2pLYLZ1S53tNmBJDS8-UGW15Pp1RnpSyAutVHM&amp;bkng_action=city&amp;dt=1626794921" role="button">
# <span class="bui-button__text">
# Log in op je account
# </span>
# </a>
# <div class="iam_login_or">
# <div class="iam_login_or_divider"></div>
# <span class="iam_login_or_text">or use one of these options</span>
# </div>
# <div class="access-panel__social-buttons">
# <a aria-label="Log in met Facebook" class="iam_login_form__social-button iam_login_form__social-button-facebook bui-button bui-button--secondary" data-component="iam/social-button" data-mask="true" data-popup-href="https://account.booking.com/auth/oauth2?aid=304142&amp;lang=nl&amp;response_type=code&amp;dt=1626794921&amp;bkng_action=city&amp;popup=1&amp;state=UtoBjLbVrbNGXySZr23dQwS_mHHpH6WH463sIj78gpuIx-2_a1VsmcKmSSSwc-oso-mrAapFVHBOocxfaT4cyBgWzWgYGJQQ8hIRnNy9J2U1ZhkyetBOX8N6zVQtZtI1cchkzezDW1I2vEbmiYTzDohvytdOjqYhpTEzqWOEBEsRL6T1VDKpxyP2YRPlCB5lXjzH-wEM59DbKjLdow-X4Xv0N2f2wMMXW9OvYmxtsf2In5zxXxGRkZBV9XKi1KDThh7KPSyhdKr_39NkI5PPNCx7TcLmrCjM6NOsMek&amp;client_id=vO1Kblk7xX9tUn2cpZLS&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;prompt=facebook" href="https://account.booking.com/auth/oauth2?response_type=code&amp;lang=nl&amp;aid=304142&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;client_id=vO1Kblk7xX9tUn2cpZLS&amp;state=UsMBjLbVrbNGXyS_PoM5BegGOmXVqVlBCMI_Pt3XWdWXAvGVoNjn1O71RzixTBd8B3JwFIXYBjbQP2rYSfBL9iXDwcc8feLTM78joVSqXIWvJkDMpvQIDP-0zpUNOCg42OboScrvnYb6yHoE7fmX7o29F3IvgR5WajQRPAI-G0kqgGIyefxlXWtVDq0eUZa0EnBZIHNpJ-KU94X1-UTTh8bPs7rklGQXtv2pLYLZ1S53tNmBJDS8-UGW15Pp1RnpSyAutVHM&amp;bkng_action=city&amp;dt=1626794921&amp;prompt=facebook" title="Log in met Facebook">
# <div class="iam_login_form__social-button-content">
# <div class="iam_login_form__social-button-image">
# <svg aria-hidden="true" class="bk-icon -social-providers-facebook" focusable="false" height="24" role="presentation" viewbox="0 0 24 24" width="24"><path d="m22.675 0h-21.35c-.732 0-1.325.593-1.325 1.325v21.351c0 .731.593 1.324 1.325 1.324h11.495v-9.294h-3.128v-3.622h3.128v-2.671c0-3.1 1.893-4.788 4.659-4.788 1.325 0 2.463.099 2.795.143v3.24l-1.918.001c-1.504 0-1.795.715-1.795 1.763v2.313h3.587l-.467 3.622h-3.12v9.293h6.116c.73 0 1.323-.593 1.323-1.325v-21.35c0-.732-.593-1.325-1.325-1.325z" fill="#4469b0"></path></svg>
# </div>
# </div>
# </a>
# <a aria-label="Log in met Google" class="iam_login_form__social-button iam_login_form__social-button-google bui-button bui-button--secondary" data-component="iam/social-button" data-mask="true" data-popup-href="https://account.booking.com/auth/oauth2?aid=304142&amp;lang=nl&amp;response_type=code&amp;dt=1626794921&amp;bkng_action=city&amp;popup=1&amp;state=UtoBjLbVrbNGXySZr23dQwS_mHHpH6WH463sIj78gpuIx-2_a1VsmcKmSSSwc-oso-mrAapFVHBOocxfaT4cyBgWzWgYGJQQ8hIRnNy9J2U1ZhkyetBOX8N6zVQtZtI1cchkzezDW1I2vEbmiYTzDohvytdOjqYhpTEzqWOEBEsRL6T1VDKpxyP2YRPlCB5lXjzH-wEM59DbKjLdow-X4Xv0N2f2wMMXW9OvYmxtsf2In5zxXxGRkZBV9XKi1KDThh7KPSyhdKr_39NkI5PPNCx7TcLmrCjM6NOsMek&amp;client_id=vO1Kblk7xX9tUn2cpZLS&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;prompt=google" href="https://account.booking.com/auth/oauth2?response_type=code&amp;lang=nl&amp;aid=304142&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;client_id=vO1Kblk7xX9tUn2cpZLS&amp;state=UsMBjLbVrbNGXyS_PoM5BegGOmXVqVlBCMI_Pt3XWdWXAvGVoNjn1O71RzixTBd8B3JwFIXYBjbQP2rYSfBL9iXDwcc8feLTM78joVSqXIWvJkDMpvQIDP-0zpUNOCg42OboScrvnYb6yHoE7fmX7o29F3IvgR5WajQRPAI-G0kqgGIyefxlXWtVDq0eUZa0EnBZIHNpJ-KU94X1-UTTh8bPs7rklGQXtv2pLYLZ1S53tNmBJDS8-UGW15Pp1RnpSyAutVHM&amp;bkng_action=city&amp;dt=1626794921&amp;prompt=google" title="Log in met Google">
# <div class="iam_login_form__social-button-content">
# <div class="iam_login_form__social-button-image">
# <svg aria-hidden="true" class="bk-icon -social-providers-google" focusable="false" height="24" role="presentation" viewbox="0 0 262 262" width="24"><path d="M255.878 133.451c0-10.734-.871-18.567-2.756-26.69H130.55v48.448h71.947c-1.45 12.04-9.283 30.172-26.69 42.356l-.244 1.622 38.755 30.023 2.685.268c24.659-22.774 38.875-56.282 38.875-96.027" fill="#4285F4"></path><path d="M130.55 261.1c35.248 0 64.839-11.605 86.453-31.622l-41.196-31.913c-11.024 7.688-25.82 13.055-45.257 13.055-34.523 0-63.824-22.773-74.269-54.25l-1.531.13-40.298 31.187-.527 1.465C35.393 231.798 79.49 261.1 130.55 261.1" fill="#34A853"></path><path d="M56.281 156.37c-2.756-8.123-4.351-16.827-4.351-25.82 0-8.994 1.595-17.697 4.206-25.82l-.073-1.73L15.26 71.312l-1.335.635C5.077 89.644 0 109.517 0 130.55s5.077 40.905 13.925 58.602l42.356-32.782" fill="#FBBC05"></path><path d="M130.55 50.479c24.514 0 41.05 10.589 50.479 19.438l36.844-35.974C195.245 12.91 165.798 0 130.55 0 79.49 0 35.393 29.301 13.925 71.947l42.211 32.783c10.59-31.477 39.891-54.251 74.414-54.251" fill="#EB4335"></path></svg>
# </div>
# </div>
# </a>
# <a aria-label="Log in met Apple" class="iam_login_form__social-button iam_login_form__social-button-apple bui-button bui-button--secondary" data-component="iam/social-button" data-mask="true" data-popup-href="https://account.booking.com/auth/oauth2?aid=304142&amp;lang=nl&amp;response_type=code&amp;dt=1626794921&amp;bkng_action=city&amp;popup=1&amp;state=UtoBjLbVrbNGXySZr23dQwS_mHHpH6WH463sIj78gpuIx-2_a1VsmcKmSSSwc-oso-mrAapFVHBOocxfaT4cyBgWzWgYGJQQ8hIRnNy9J2U1ZhkyetBOX8N6zVQtZtI1cchkzezDW1I2vEbmiYTzDohvytdOjqYhpTEzqWOEBEsRL6T1VDKpxyP2YRPlCB5lXjzH-wEM59DbKjLdow-X4Xv0N2f2wMMXW9OvYmxtsf2In5zxXxGRkZBV9XKi1KDThh7KPSyhdKr_39NkI5PPNCx7TcLmrCjM6NOsMek&amp;client_id=vO1Kblk7xX9tUn2cpZLS&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;prompt=apple" href="https://account.booking.com/auth/oauth2?response_type=code&amp;lang=nl&amp;aid=304142&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;client_id=vO1Kblk7xX9tUn2cpZLS&amp;state=UsMBjLbVrbNGXyS_PoM5BegGOmXVqVlBCMI_Pt3XWdWXAvGVoNjn1O71RzixTBd8B3JwFIXYBjbQP2rYSfBL9iXDwcc8feLTM78joVSqXIWvJkDMpvQIDP-0zpUNOCg42OboScrvnYb6yHoE7fmX7o29F3IvgR5WajQRPAI-G0kqgGIyefxlXWtVDq0eUZa0EnBZIHNpJ-KU94X1-UTTh8bPs7rklGQXtv2pLYLZ1S53tNmBJDS8-UGW15Pp1RnpSyAutVHM&amp;bkng_action=city&amp;dt=1626794921&amp;prompt=apple" title="Log in met Apple">
# <div class="iam_login_form__social-button-content">
# <div class="iam_login_form__social-button-image">
# <svg aria-hidden="true" class="bk-icon -social-providers-apple" focusable="false" height="24" role="presentation" viewbox="0 0 170 170" width="24"><path d="M150.37 130.25c-2.45 5.66-5.35 10.87-8.71 15.66-4.58 6.53-8.33 11.05-11.22 13.56-4.48 4.12-9.28 6.23-14.42 6.35-3.69 0-8.14-1.05-13.32-3.18-5.197-2.12-9.973-3.17-14.34-3.17-4.58 0-9.492 1.05-14.746 3.17-5.262 2.13-9.501 3.24-12.742 3.35-4.929.21-9.842-1.96-14.746-6.52-3.13-2.73-7.045-7.41-11.735-14.04-5.032-7.08-9.169-15.29-12.41-24.65-3.471-10.11-5.211-19.9-5.211-29.378 0-10.857 2.346-20.221 7.045-28.068 3.693-6.303 8.606-11.275 14.755-14.925s12.793-5.51 19.948-5.629c3.915 0 9.049 1.211 15.429 3.591 6.362 2.388 10.447 3.599 12.238 3.599 1.339 0 5.877-1.416 13.57-4.239 7.275-2.618 13.415-3.702 18.445-3.275 13.63 1.1 23.87 6.473 30.68 16.153-12.19 7.386-18.22 17.731-18.1 31.002.11 10.337 3.86 18.939 11.23 25.769 3.34 3.17 7.07 5.62 11.22 7.36-.9 2.61-1.85 5.11-2.86 7.51zM119.11 7.24c0 8.102-2.96 15.667-8.86 22.669-7.12 8.324-15.732 13.134-25.071 12.375a25.222 25.222 0 0 1-.188-3.07c0-7.778 3.386-16.102 9.399-22.908 3.002-3.446 6.82-6.311 11.45-8.597 4.62-2.252 8.99-3.497 13.1-3.71.12 1.083.17 2.166.17 3.24z"></path></svg>
# </div>
# </div>
# </a>
# </div>
# <div class="iam_login_text iam_login_text--footer">
# Nog geen account? <a class="iam_login_link" href="https://account.booking.com/auth/oauth2?response_type=code&amp;lang=nl&amp;aid=304142&amp;redirect_uri=https%3A%2F%2Fsecure.booking.com%2Flogin.html%3Fop%3Doauth_return&amp;client_id=vO1Kblk7xX9tUn2cpZLS&amp;state=UsMBjLbVrbNGXyS_PoM5BegGOmXVqVlBCMI_Pt3XWdWXAvGVoNjn1O71RzixTBd8B3JwFIXYBjbQP2rYSfBL9iXDwcc8feLTM78joVSqXIWvJkDMpvQIDP-0zpUNOCg42OboScrvnYb6yHoE7fmX7o29F3IvgR5WajQRPAI-G0kqgGIyefxlXWtVDq0eUZa0EnBZIHNpJ-KU94X1-UTTh8bPs7rklGQXtv2pLYLZ1S53tNmBJDS8-UGW15Pp1RnpSyAutVHM&amp;bkng_action=city&amp;dt=1626794921&amp;prompt=register">Je account aanmaken</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="logo-not-document-write" style="display: none;"></div>
# <script nonce="K1kLW5Ph1ocREa4" type="text/javascript">
# setTimeout(function(){
# var img = new Image(1,1);
# img.src = '/logo?ver=1&sid=&t='+1626794920+1;
# },0);
# </script>
# <noscript>
# <img src="/logo?ver=0&amp;sid=&amp;t=1626794920" style="display:none"/>
# </noscript>
# <div style="display: none;">
# <svg aria-hidden="true" class="bk-icon -fonticon-aclose" focusable="false" height="32" role="presentation" viewbox="0 0 36 32" width="36">
# <path d="M34 3.2L30.8 0 18 12.8 5.2 0 2 3.2 14.8 16 2 28.8 5.2 32 18 19.2 30.8 32l3.2-3.2L21.2 16 34 3.2z"></path>
# </svg>
# <svg aria-hidden="true" class="bk-icon -fonticon-downchevron" focusable="false" height="32" role="presentation" viewbox="0 0 51 32" width="51">
# <path d="M45.1.2L25.7 19.7 6.3.2 0 6.5l25.7 25.7L51.4 6.5z"></path>
# </svg>
# <svg aria-hidden="true" class="bk-icon -fonticon-upchevron" focusable="false" height="32" role="presentation" viewbox="0 0 51 32" width="51">
# <path d="M6.3 32.2l19.4-19.5 19.4 19.5 6.3-6.3L25.7.2 0 25.9z"></path>
# </svg>
# <svg aria-hidden="true" class="bk-icon -fonticon-checkempty" focusable="false" height="32" role="presentation" viewbox="0 0 32 32" width="32">
# <path d="M16 30c7.732 0 14-6.268 14-14S23.732 2 16 2 2 8.268 2 16s6.268 14 14 14zm0 2C7.163 32 0 24.837 0 16S7.163 0 16 0s16 7.163 16 16-7.163 16-16 16z"></path>
# </svg>
# <svg aria-hidden="true" class="bk-icon -fonticon-checkno2" focusable="false" height="32" role="presentation" viewbox="0 0 32 32" width="32">
# <path d="M16 30c7.732 0 14-6.268 14-14S23.732 2 16 2 2 8.268 2 16s6.268 14 14 14zm0 2C7.163 32 0 24.837 0 16S7.163 0 16 0s16 7.163 16 16-7.163 16-16 16z"></path>
# <path d="M24.587 11.039L13.825 21.583c-.054.09-.12.182-.208.271l-.504.505c-.278.278-.607.403-.733.276l-5.125-5.366c-.126-.126-.002-.454.276-.732l.504-.505c.279-.279.607-.403.733-.277l3.842 4.022L23.073 9.525a.715.715 0 0 1 1.009 0l.505.505a.715.715 0 0 1 0 1.009z"></path>
# </svg>
# </div>
# <span id="req_info" style="display:none;">1362650|1,1358030,1365650,1357280,1363830,1369160</span>
# </body>
# </html>

# %%
names = doc.find_all('span', itemprop='name')

# %%
prices = doc.find_all(class_='bui-price-display__value bui-f-color-constructive')

# %%
for price, name in zip(prices, names):
    print('---')
    print(name.text)
    print(price.text)
# Out:
# ---
#
# Hampton By Hilton Hamburg City Centre
#
# € 84,15
# ---
#
# Barceló Hamburg
#
# € 121,30
# ---
#
# Radisson Blu Hotel, Hamburg
#
# € 115,75
# ---
#
# Courtyard by Marriott Hamburg City
#
# € 74,25
# ---
#
# Hyperion Hotel Hamburg
#
# € 107,20
# ---
#
# Crowne Plaza Hamburg City Centre, an IHG Hotel
#
# € 89
# ---
#
# Holiday Inn - Hamburg - Berliner Tor, an IHG Hotel
#
# € 79
# ---
#
# Scandic Hamburg Emporio
#
# € 87
# ---
#
# INNSiDE by Meliá Hamburg Hafen
#
# € 85
# ---
#
# Super 8 by Wyndham Hamburg Mitte
#
# € 63

# %%
rows = []

for price, name in zip(prices, names):
    row = {}
    print('---')
    #print(name.text)
    #print(price.text)
    row['Hotel'] = name.text
    row['Price'] = price.text
    print(row)
    rows.append(row)
# Out:
# ---
# {'Hotel': '\nHampton By Hilton Hamburg City Centre\n', 'Price': '€\xa084,15'}
# ---
# {'Hotel': '\nBarceló Hamburg\n', 'Price': '€\xa0121,30'}
# ---
# {'Hotel': '\nRadisson Blu Hotel, Hamburg\n', 'Price': '€\xa0115,75'}
# ---
# {'Hotel': '\nCourtyard by Marriott Hamburg City\n', 'Price': '€\xa074,25'}
# ---
# {'Hotel': '\nHyperion Hotel Hamburg\n', 'Price': '€\xa0107,20'}
# ---
# {'Hotel': '\nCrowne Plaza Hamburg City Centre, an IHG Hotel\n', 'Price': '€\xa089'}
# ---
# {'Hotel': '\nHoliday Inn - Hamburg - Berliner Tor, an IHG Hotel\n', 'Price': '€\xa079'}
# ---
# {'Hotel': '\nScandic Hamburg Emporio\n', 'Price': '€\xa087'}
# ---
# {'Hotel': '\nINNSiDE by Meliá Hamburg Hafen\n', 'Price': '€\xa085'}
# ---
# {'Hotel': '\nSuper 8 by Wyndham Hamburg Mitte\n', 'Price': '€\xa063'}

# %%
df = pd.DataFrame(rows)
df
# Out:
#                                                Hotel     Price
# 0          \nHampton By Hilton Hamburg City Centre\n   € 84,15
# 1                                \nBarceló Hamburg\n  € 121,30
# 2                    \nRadisson Blu Hotel, Hamburg\n  € 115,75
# 3             \nCourtyard by Marriott Hamburg City\n   € 74,25
# 4                         \nHyperion Hotel Hamburg\n  € 107,20
# 5  \nCrowne Plaza Hamburg City Centre, an IHG Hot...      € 89
# 6  \nHoliday Inn - Hamburg - Berliner Tor, an IHG...      € 79
# 7                        \nScandic Hamburg Emporio\n      € 87
# 8                 \nINNSiDE by Meliá Hamburg Hafen\n      € 85
# 9               \nSuper 8 by Wyndham Hamburg Mitte\n      € 63

# %%
df=df.replace(to_replace = '€', value ='')
df
# Out:
#                                                Hotel     Price
# 0          \nHampton By Hilton Hamburg City Centre\n   € 84,15
# 1                                \nBarceló Hamburg\n  € 121,30
# 2                    \nRadisson Blu Hotel, Hamburg\n  € 115,75
# 3             \nCourtyard by Marriott Hamburg City\n   € 74,25
# 4                         \nHyperion Hotel Hamburg\n  € 107,20
# 5  \nCrowne Plaza Hamburg City Centre, an IHG Hot...      € 89
# 6  \nHoliday Inn - Hamburg - Berliner Tor, an IHG...      € 79
# 7                        \nScandic Hamburg Emporio\n      € 87
# 8                 \nINNSiDE by Meliá Hamburg Hafen\n      € 85
# 9               \nSuper 8 by Wyndham Hamburg Mitte\n      € 63

# %%
df.to_csv("hamburghotelprices.csv")
#import csv and append it
#https://www.programiz.com/python-programming/datetime/current-datetime adding the data
#put it before the scrape
